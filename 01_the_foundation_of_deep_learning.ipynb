# %% [markdown]
# # Chapter 1 -  Foundation of Deep Learning

# %% [markdown]
# ### Vectorized vs for loop

# %%
import numpy as np
import time

a = np.random.rand(100000)
b = np.random.rand(100000)

c = 0
tic = time.time()
for i in range(100000):
    c += a[i]*b[i]
toc = time.time()

print(c)
print("for loop:" + str(1000*(toc-tic)) + "ms")

c = 0
tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized:" + str(1000*(toc-tic)) + "ms")
# Out:
# 24870.24330626313
# for loop:51.16724967956543ms
# 24870.243306263183
# Vectorized:0.9710788726806641ms

# %% [markdown]
# ## Matplotlib 绘图

# %% [markdown]
# ### 绘制一般图形 plot

# %%
# import library
import numpy as np
import matplotlib.pyplot as plt

# generate data
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)

# Plot the figure
plt.plot(x, y)
plt.show()  # You must call plt.show() to make graphics appear.

# %%
# import library
import numpy as np
import matplotlib.pyplot as plt

# generate data
x = np.arange(0, 4 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the the figure
plt.plot(x, y_sin)
plt.plot(x, y_cos, '--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sin and Cos')
plt.legend(['Sin', 'Cosin'])
plt.show()

# %% [markdown]
# ### 散点图 scatter

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate data
x = np.random.randn(200)
y = np.random.randn(200)
# draw scatter plots
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate data
x1 = np.random.randn(200)
y1 = np.random.randn(200)
x2 = np.random.randn(200) + 3
y2 = np.random.randn(200) + 3
# draw scatter plots
plt.scatter(x1, y1, marker='o')
plt.scatter(x2, y2, marker='s')
plt.show()

# %% [markdown]
# ### 显示图像 picture

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

# read the image
img = imread('./datasets/ch01/python.jpg')

# Show the original image
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (494, 495)
